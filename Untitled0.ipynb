# %% [markdown]
# <a href="https://colab.research.google.com/github/damarks80/aws-cloudformation-simplified/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data=[['Jill',20,3.1,'False'], ['Jerome',20,3.2,'True'],
['Deepak', 21, 2.8,'False'],['Taylor', 19,3.3, 'True']]
df = pd.DataFrame(data, columns=['Name', 'Age', 'GPA', 'Business Major'])
df
# Out:
#      Name  Age  GPA Business Major
# 0    Jill   20  3.1          False
# 1  Jerome   20  3.2           True
# 2  Deepak   21  2.8          False
# 3  Taylor   19  3.3           True

# %%
df[['Age']].describe()
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot (y=df["Business Major"],
x=df["GPA"] );
plt.show()
